# %%
print("Git Learning")
# Out:
# Git Learning

# %%
print("2nd Commit Try and Git Status Check")
# Out:
# 2nd Commit Try and Git Status Check

# %%
print("Changes in future ")
# Out:
# Changes in future

# %%
print("Final Change")
# Out:
# Final Change

# %%
print("Changes in future ")
# Out:
# Changes in future
